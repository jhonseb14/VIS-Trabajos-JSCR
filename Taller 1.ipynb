# %% [markdown]
# # *Taller* *1* *Solución.*

# %% [markdown]
# ### Universidad Santo Tomas.
# ### Jhon Sebastian Castro Reyes.
# ### Visualización de Datos en Phyton.
#
# #### 2021-1

# %% [markdown]
# primero encontrar las dos visualizaciones que trabajare para este anailisis critico.
#
# ¿que?¿porque?¿como?
#
# 1.  ¿Que?
#
# ¿Qué datos ve el usuario?
#   * RTA// el usuario ve diferentes tipos de vinos y alimentos junto a combinaciones
#
# ¿Qué tipo de datos se proporcionan?
#   * RTA// vemos que es un tipo de atributo categorico(cualitativo), pueden considararse como data sets ¿de que tipo?, claramente se ve una       forma de Networks & Trees
#
# ¿Qué información puedes deducir de los datos,
# frente a los significados que te deben decir
# explícitamente?
#   *  RTA// se puede deducir cual podria ser la mejor elccion de vino para una comida, pero hay que tener en cuenta que
#      los vinos son mas grandes por lo que llaman mas la atencion, donde se puede considerar que cual seria la mejor comida
#      para cierto tipo de vino.
#
# ¿Qué conceptos de alto nivel te permitirán dividir
# los conjuntos de datos en piezas generales y
# útiles?
#   * RTA // su concepto de mas alto nivel es consume que seria descubir o explorar contra presentar o explicar, luego disffrutar
#
#
# 2.  ¿Porque?
#
# ¿Qué tipo de tarea requiere el usuario?
#   * presuntamente se quiere mostrar que comida seria mejor elegir, al momento de tomar un determinado vino.
#
# NOTA: "bueno continuando con el porque sabemos que no contamos con informacion suficiente como para responder muy
# consisamente con las preguntas del por que ya que necesitamos al experto o usuario"
#
# * los Objetivos encontrar el camino entre dos puntos o dos nodos, sabemos que esto pertenece al network data.
#
# * actions; sabemos que sus acciones son presentar localizar y identificar datos segun si requiera el usuario o experto
#   en el tema estudiado. que estas acciones son conocidas mas que todo por ser de medio o bajo nivel.

# %% [markdown]
# ![pairing-wine-and-food.png](attachment:pairing-wine-and-food.png)

# %% [markdown]
# principalmente esta visualizacion no tiene marca, pero si tiene canales y usa algunos canales como lo seria el color, que nos permiten diferenciar los colores, tambien tiene icolnos que diferencian unos de los otros, y se podria considerar que no tienen ninguna marca.
#
# podria considerarse que tiene eficacia y efectivida. tambien carcateristicas de identidad como el color y shape.
# puede verse en el espacio de agrupacion.
#
# critica, desde mi punto de vista la visualiacion es buena ya que permite que el usuario entienda perfectaente la visalizacion,
# de otra manera creo que los colores juegan un rol muy importante que podria llevar problemas en las interacciones con personas
# que pueden padecer algun tipo de daltonismo.

# %% [markdown]
# La siguiete visualizacion es de una nube de palabras utilizada para mirar tendencias de busqueda
#
# ¿que?¿porque?¿como?
#
# ¿Que?
# ¿Qué datos ve el usuario?
#
#  - RTA// el usuario pofra observar los diferentes tipos de tendencias segun las palabras en la nube de  palabras
#
# ¿Qué tipo de datos se proporcionan?
#
#  - RTA// vemos que es un tipo de atributo categorico(cualitativo), pueden considararse como data sets demtipo ordenado
#
# ¿Qué información puedes deducir de los datos, frente a los significados que te deben decir explícitamente?
#
# - RTA// se puede deducir que la palabra mas grande sera la palabla mas buscada y la tendencia pero las palabras al rededor no     serantendencia pero en menor proporcion, o tambien considerado como cluster, sets, lists las cuales determinan el
#   orden o el pocicionamiento segun las tendencias de busqueda. y categorico
#
# ¿Qué conceptos de alto nivel te permitirán dividir los conjuntos de datos en piezas generales y útiles?
#
#   - RTA // no estoy del todo seguro si su consepto de alto nivel es "producir" ya que de los resultados de busqueda o las maximas busquedas que ocurran en el busacador derivaran donde se consentra la informacion osea cuales seran las tendencias
#
# ¿Porque?
# ¿Qué tipo de tarea requiere el usuario?
#
# - Presuntamente el usuario o persona encargada del buscador o persona que obtiene bases de datos con informacion de las busquedas requiere visualizar las tendencias de busqueda en su buscador, poniendo en primeros lugares las palabras mas buscadas.
#
# NOTA: "bueno continuando con el porque sabemos que no contamos con informacion suficiente como para responder muy
# consisamente con las preguntas del por que ya que necesitamos al experto o usuario"
#
# - los Objetivos encontrar la tendencia del buscador y colocarlo de manera ordenada en la nube de palabras
#
# -
# actions; sabemos que sus acciones son presentar localizar y identificar datos segun si requiera el usuario o experto en el tema estudiado. que estas acciones son conocidas mas que todo por ser de medio o bajo nivel.

# %% [markdown]
# ![Captura.PNG](attachment:Captura.PNG)

# %% [markdown]
# esta visualizacion no tiene una marca especifica ya que no tiene marca de lineas ni de puntos ni es geometrica, desde un punto de vista del usuario, vemos que tiene diversos canales como el color y la forma o en este caso seria las palabras o su nombre, por otro lado podemos ver que tiene otro canal como lo es la area de las palabras en tendencia, entre mas grande la tendencia mas grande sera la palabra y asi ocurre en el caso inverso. podriamos considerar que esta en una region espacial.
#
# la visualizacion es efectiva ya que permite ver las palabras, depronto podria no ser tan util si una persona sufre de algun tipo de daltonismo ya que tiene verdes y colores que podrian ponerse y diferenciarce con una escala de color mejor tambien no es muy claro si el tamaño define la tendenia o el largo de la palabra tambien la podria definir es efectiva pero el mismo tiempo es confusa.

# %% [markdown]
# ## Bibliografia.
#
# todo lo encontrado esta en estos links:
#
# [Toucantoco](https://toucantoco.com/blog/es/7-ejemplos-de-data-visualizacion/).
#
# [dbibyhavas](https://dbibyhavas.io/es/blog/visualizacion-de-datos-10-graficos-para-visualizar-tus-datos-de-analitica/).
